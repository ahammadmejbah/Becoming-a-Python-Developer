# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Question 1: What is the "str" data type used for in Python?

# %%
str_var = "Bytes of Intelligence"
print(str_var)
# Out:
# Bytes of Intelligence

# %% [markdown]
# Question 2: How can you create an empty string in Python?

# %%
str_var = " "
print(str_var)

# %% [markdown]
# Question 3: Can you concatenate two strings in Python? If yes, provide an example.

# %%
str_var = "Bytes of"
str_var2 = "Intelligence"
concat = str_var + " " + str_var2
print(concat)
# Out:
# Bytes of Intelligence

# %% [markdown]
# Question 4: How can you find the length of a string in Python?

# %%
str_var = "Bytes of Intelligence"
len_of_string = len(str_var)
print("String Length: ", len_of_string)
# Out:
# String Length:  21

# %% [markdown]
# Question 5: Explain the difference between indexing and slicing in strings.

# %%
str_var = "Bytes of Intelligence"
for i in range(0, len(str_var)):
    print(f"Index value is {i} and Char is {str_var[i]}")
# chr_01 = str_var[10]
# print(chr_01)
# Out:
# Index value is 0 and Char is B
# Index value is 1 and Char is y
# Index value is 2 and Char is t
# Index value is 3 and Char is e
# Index value is 4 and Char is s
# Index value is 5 and Char is
# Index value is 6 and Char is o
# Index value is 7 and Char is f
# Index value is 8 and Char is
# Index value is 9 and Char is I
# Index value is 10 and Char is n
# Index value is 11 and Char is t
# Index value is 12 and Char is e
# Index value is 13 and Char is l
# Index value is 14 and Char is l
# Index value is 15 and Char is i
# Index value is 16 and Char is g
# Index value is 17 and Char is e
# Index value is 18 and Char is n
# Index value is 19 and Char is c
# Index value is 20 and Char is e

# %%
str_var = "Bytes of Intelligence"

chr_01 = str_var[0:5]
print(chr_01)
# Out:
# Bytes

# %% [markdown]
# Question 6: How can you convert a string to lowercase in Python?

# %%
str_var = "Bytes of Intelligence"
lower_case = str_var.lower()
print(f"Lower String : {lower_case}")
# Out:
# Lower String : bytes of intelligence

# %%
str_var = "Bytes of Intelligence"
lower_case = str_var.upper()
print(f"Modified String : {lower_case}")
# Out:
# Modified String : BYTES OF INTELLIGENCE

# %%
str_var = "Bytes of Intelligence"
lower_case = str_var.capitalize()
print(f"Modified String : {lower_case}")
# Out:
# Modified String : Bytes of intelligence

# %%
str_var = "Bytes of intelligence"
lower_case = str_var.title()
print(f"Modified String : {lower_case}")
# Out:
# Modified String : Bytes Of Intelligence

# %% [markdown]
# Question 7: Can you check if a specific substring is present in a string? If yes, provide an example.

# %%
str_var = "Bytes of Intelligence"
sub_string = "Intelligence"
check_string = sub_string in str_var
print(f"Modified String : {check_string}")
# Out:
# Modified String : True

# %% [markdown]
# Question 8: How can you split a string into a list of substrings based on a delimiter?

# %%
str_var = "Bytes of Intelligence"
string = str_var.split(" ")
print(f"Modified String : {string}")
# Out:
# Modified String : ['Bytes', 'of', 'Intelligence']

# %% [markdown]
# Question 9: Explain the difference between strip(), lstrip(), and rstrip() methods for strings.

# %%
str_var = "    Bytes of   Intelligence          "
#1. strip ()
string = str_var.strip()
print(f"Modified String : {string}")
# 2. lstrip
lstring = str_var.lstrip()
print(f"Modified String : {lstring}")
# 3. rstrip
rstring = str_var.rstrip()
print(f"Modified String : {rstring}")
# Out:
# Modified String : Bytes of   Intelligence
# Modified String : Bytes of   Intelligence
# Modified String :     Bytes of   Intelligence

# %% [markdown]
# Question 10: How can you format strings in Python? Provide an example using f-strings.

# %%
name = "Mejbah Ahammad"
age = 100
height = 100
string_format = f"My Name is {name} and My Age is :{age} and My height is :{height}"
print(string_format)
# Out:
# My Name is Mejbah Ahammad and My Age is :100 and My height is :100

# %%
name = "Mejbah Ahammad"
age = 100
height = 100
string_format = f"My Name is: {name}\nMy Age is :{age}\nMy height is :{height}"
print(string_format)
# Out:
# My Name is: Mejbah Ahammad
# My Age is :100
# My height is :100

# %%
name = "Mejbah Ahammad"
age = 100
height = 100
string_format = f"My Name is:\t{name}\nMy Age is:\t{age}\nMy height is:\t{height}"
print(string_format)
# Out:
# My Name is:	Mejbah Ahammad
# My Age is:	100
# My height is:	100

# %% [markdown]
# Question 11: How can you replace a specific substring in a string with another substring?

# %%
str_var = "Bytes of Intelligence"
variable_replace = str_var.replace("Intelligence", "Intelligence: Exploring AI S.")
print(variable_replace)
# Out:
# Bytes of Intelligence: Exploring AI S.

# %% [markdown]
# Question 12: Can you check if a string starts or ends with a specific substring? If yes, provide an example.

# %%
str_var = "Bytes of Intelligences"
variable_replace = str_var.startswith("Bytes")
print(variable_replace)
# Out:
# True

# %% [markdown]
# Question 13: How can you convert a string to uppercase in Python?

# %%
str_var = "Bytes of Intelligences"
variable_replace = str_var.upper()
print(variable_replace)
# Out:
# BYTES OF INTELLIGENCES

# %% [markdown]
# Question 14: What is the difference between find() and index() methods for strings?

# %%
str_var = "Bytes of Intelligences"
variable_find = str_var.find("s")
print(variable_find)
# Out:
# 4

# %%
str_var = "Bytes of Intelligences"
variable_find = str_var.index("Bytes")
print(variable_find)
# Out:
# 0

# %%
str_var = "Bytes of Intelligences"
variable_find = str_var.find("Bytess")
print(variable_find)

try: 
    indexValue = str_var.index("Bytesss")
    print(indexValue)
except ValueError:
    indexValue = -1
    print(indexValue)
# Out:
# -1
# -1

# %% [markdown]
# Question 15: How can you reverse a string in Python? Provide an example.

# %%
str_var = "Bytes of Intelligences"
reverse_string = str_var[::-2]
print(reverse_string)
# Out:
# sceiltIf ey

# %% [markdown]
# Question 16: How can you count the occurrences of a specific substring in a string?

# %%
str_var = "Bytes of Intelligences"
string_count = str_var.count("te")
print(string_count)
# Out:
# 2

# %% [markdown]
# Question 17: Explain the difference between the join() method and the + operator for concatenating strings in Python.

# %%
str_var = ["Bytes", "of", "Intelligences"]
joinString = "--".join(str_var)
print(joinString)
# Out:
# Bytes--of--Intelligences

# %%
"Bytes"+ " of" + " Intelligences"
# Out:
# 'Bytes of Intelligences'

# %% [markdown]
# Question 18: How can you check if all characters in a string are alphanumeric?

# %%
strD = 'Bytes of Intelligences2541'
number_check = strD.isalnum()
print(number_check)
# Out:
# False

# %%
strD = '4765464652541'
number_check = strD.isalnum()
print(number_check)
# Out:
# True

# %% [markdown]
# Question 19: How can you capitalize the first letter of each word in a string?

# %%
strD = "how can you capitalize the first letter of each word in a string"
cap = strD.title()
print(cap)
# Out:
# How Can You Capitalize The First Letter Of Each Word In A String

# %% [markdown]
# Question 20: Can you check if a string is entirely in lowercase or uppercase? If yes, provide an example.

# %%
strD ="How Can You Capitalize The First Letter Of Each Word In A String"
l_string = strD.islower()
u_string = strD.isupper()
print("Lower: ", l_string)
print("Upper: ", u_string)
# Out:
# Lower:  False
# Upper:  False

# %%
strD ="How Can You Capitalize The First Letter Of Each Word In A String"
l_string = strD.lower().islower()
u_string = strD.upper().isupper()
print("Lower: ", l_string)
print("Upper: ", u_string)
# Out:
# Lower:  True
# Upper:  True
